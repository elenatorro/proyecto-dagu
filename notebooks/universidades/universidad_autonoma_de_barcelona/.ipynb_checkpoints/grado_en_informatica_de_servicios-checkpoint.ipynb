# %%
degrees = [
    ['Grado en Informática y Servicios', 'https://www.uab.cat/web/estudiar/listado-de-grados/informacion-general/informatica-y-servicios-escuela-adscrita-1216708258897.html?param1=1231314915546'],
    ['Grado en Ingeniería de Datos', 'https://www.uab.cat/web/estudiar/listado-de-grados/plan-de-estudios/plan-de-estudios-y-horarios/ingenieria-de-datos-1345467893054.html?param1=1345740029761'],
    ['Grado en Ingeniería Informática', 'https://www.uab.cat/web/estudiar/listado-de-grados/informacion-general/x-1216708258897.html?param1=1263367146646']
]

# %%
DEGREE_DATA = [
    ['code', '21046'],
    ['university', 'Universidad Autónoma de Barcelona'],
    ['name', 'Grado en Informática y Servicios'],
    ['description', 'La Ingeniería Informática de Servicios está revolucionando la economía global a través del desarrollo de nuevos productos y servicios digitales.'],
    ['summary', '''
        El grado de Informática y Servicios (titulación del ámbito de conocimiento de la ingeniería informática) destaca por su enfoque profesionalizador, que proporciona al estudiante conocimientos organizativos y tecnológicos que le permitan acceder a un mercado laboral en constante crecimiento basado en la transformación digital.
        Fruto de la evolución de la ingeniería técnica en Informática de Gestión y del grado en Multimedia, el grado en Informática y Servicios pone especial foco en la innovación formativa dentro del espacio europeo de educación superior, con un modelo docente centrado en las necesidades del estudiante.
        De esta manera, el alumno se convierte en el auténtico protagonista de su carrera universitaria y desarrolla un papel más participativo durante los estudios, acompañado por docentes que ofrecen una tutorización y una orientación profesional personalizadas.
        La relación estrecha entre las Escuelas Universitarias Gimbernat y el sector empresarial ha garantizado siempre una excelente ocupabilidad de nuestros graduados en empresas de servicios y del sector tecnológico.
        Al finalizar los estudios, el estudiante obtendrá el título oficial de graduado/a en Informática y Servicios por la Universidad Autónoma de Barcelona.
    '''],
    ['area', 'Campus de Sant Cugat del Vallès'],
    ['years', 4],
    ['num_credits', 240],
    ['faculty', 'Escuela Universitaria de Informática "Tomàs Cerdà" (centro adscrito)'],
    ['url', 'https://www.uab.cat/web/estudiar/listado-de-grados/informacion-general-1216708258897.html?param1=1231314915546'],
    ['price_1', 99.38],
    ['price_2', 99.38],
    ['price_3', 99.38],
    ['price_4', 99.38],
    ['total_min_price', 240 * 99.38],
    ['admission_mark', 5.00]
    ['profile', '''
        Capacidad de abstracción, percepción y atención.
        Imaginación y creatividad.
        Capacidad de trabajo en equipo y de planificación del trabajo.
        Capacidad de innovación.
        Razonamiento lógico.
        Visión espacial.
        Aptitud numérica
        Interés por las cuestiones sociales, por la economía y la empresa.
        Facilidad de expresión.
        Capacidad de síntesis.
        Carácter sociable y extrovertido.
        Por lo que hace referencia a los conocimientos de una tercera lengua, será suficiente el nivel conseguido por el estudiante en sus estudios de bachillerato. Dicho nivel debe permitir al estudiante la adaptación al modelo de introducción progresiva de asignaturas impartidas en inglés, que culminará con la elaboración, presentación y defensa del Trabajo Final de Grado en inglés.
    '''],
    ['opportunities', '''
        Analista y programador de Sistemas de información de servicios y multimedia (bases de datos, portales, libros electrónicos).
        Analista y programador de Sistemas de comunicación multimedia (videoconferencias, teleservicios).
        Analista y programador de Sistemas de negocio de servicios y multimedia (comercio electrónico, marketing multimedia).
        Consultor y auditor de sistemas de información de servicios y multimedia.
    '''],
    ['languages', 'Inglés, Español, Catalán'],
    ['learning_mode', 'presencial'],
    ['mobility_program', '''
        La escuela tiene firmados convenios de intercambio dentro del programa Erasmus+ con las universidades de Aveiro (Portugal), Linnaeus University (Suecia), Nancy (Francia), Turín y Génova (Italia) y Aalborg (Dinamarca).
    '''],
    ['working_practices', '''
        Dentro de la asignatura optativa Prácticas Externas de 4º curso, el estudiante puede realizar prácticas en una empresa del sector.
    ''']
    ['basic_skills', '''    
        Poseer y comprender los conocimientos que le permitirán integrar soluciones informáticas multimedia y procesos empresariales para satisfacer las necesidades de información de las organizaciones, permitiéndoles alcanzar sus objetivos de manera efectiva y eficiente en términos de coste, dándoles así ventajas competitivas.
        Aplicar de forma apropiada teorías, procedimientos y herramientas propios de la ingeniería en el desarrollo profesional de la informática (especificación, diseño, implementación, despliegue -implantación- y evaluación de productos) de manera que se demuestre la comprensión de los compromisos adoptados en las decisiones de diseño.
        Emitir juicios y valoraciones, con los datos recogidos  a partir del análisis de los requerimientos formulados por una empresa o institución, con el objetivo de implementar sistemas de información que la integren, presentada de diversas formas (texto, imagen, audio, animaciones, video, etc.).
        Plantear, redactar y exponer oralmente proyectos informáticos para el sector servicios, tanto para empresas como para instituciones, con la finalidad de que mejoren sus ámbitos de trabajo y sus negocios.
        Dirigir y responsabilizarse de la puesta en marcha y la mejora constante de los proyectos informáticos elaborados, así como ser capaz de valorar su impacto económico y social.
        Desarrollar el grado suficiente de autonomía para emprender estudios especializados de su rama de conocimiento o estudios de cualquier otro tipo, con el denominador común de proporcionarle formación continuada a lo largo de toda su vida profesional.
    '''],
    ['specific_skills', '''
        Demostrar conocimiento y comprensión de hechos esenciales, conceptos, principios y teorías relativas a la informática, así como al espectro de sus disciplinas de referencia.
        Diseñar sistemas de información de forma robusta teniendo en cuenta restricciones de tiempo y coste.
        Evaluar sistemas hardware/software en función de un criterio de calidad determinado.
        Encontrar soluciones algorítmicas a problemas, comprendiendo la idoneidad y complejidad de las soluciones propuestas.
        Demostrar conocimiento y comprensión del contexto económico y organizativo en el que desarrolla su trabajo.
        Analizar, identificar y definir los requisitos que deben satisfacerse para resolver problemas o conseguir objetivos tanto de organizaciones como de personas.
        Analizar el papel y la evolución de las tecnologías de la información (TIC y Multimedia) para su inclusión en los servicios con el objetivo de mejorar sus características.
        Diseñar la arquitectura, uso, accesibilidad y diseño gráfico del sistema de  información de la empresa de servicios considerando la  experiencia del usuario (user/costumer experience).
        Integrar distintos sistemas de información multimedia así como la variedad de elementos que lo componen (imágenes, audio, vídeos, animaciones, simulaciones…).
        Adoptar la tecnología para que sea realmente eficiente en su papel de intermediario en el proceso comunicativo entre las empresas de servicios y los usuarios de dichos sistemas.
        Identificar los mecanismos que permiten la mejora y evaluación de la productividad y calidad de los servicios, mediante la introducción de procesos de innovación, orientados a la satisfacción del usuario.
    '''],
    ['transversal_skills', '''
        Razonar y pensar científicamente buscando soluciones a los problemas a través de una visión global del contexto.
        Trabajar de manera autónoma, gestionando el tiempo y los recursos disponibles.
        Trabajar en equipo, en entornos multidisciplinarios y multilingües, respetando el rol de los diversos miembros del equipo.
        Comunicarse y transmitir ideas y resultados de manera efectiva a un público especializado y no especializado, también en inglés.
        Asumir la responsabilidad social, ética, profesional y legal que se derive del ejercicio de la práctica profesional.
        Demostrar orientación hacia la calidad y la mejora contínua, manteniéndose al día en el mundo de la ingeniería.
    '''],
    ['double_degree', False],
    ['schedule', 'lunes a viernes, de 16h a 22h'],
    ['subjects', '200324,']
]

# %% [markdown]
# ## Primero

# %%
DEGREE_SUBJECTS_1 = [
 ['code', '200324'],
 ['name', 'Matemáticas para la computación y los servicios'],
 ['subject_type', 'Formación Básica'],
 ['num_credits', 12],
 ['period', 'Anual'],
 ['course', 1]
 ['language', 'Catalán'],
 ['content', '''
    UNIDAD TEMÁTICA 1: INTRODUCCIÓN AL ÁLGEBRA LINEAL
    Tema 1: Teoría de conjuntos.
    Tema 2: Matrices y determinantes.
    Tema 3: Sistemas de ecuaciones lineales.
    Tema 4: Espacios Vectoriales y aplicaciones lineales.
    UNIDAD TEMÁTICA 2: FUNDAMENTOS DE MATEMÁTICA DISCRETA
    Tema 1: Introducción a la lógica matemática.
    Tema 2: Relaciones binarias.
    Tema 3: Teoría de números. Divisibilidad. Aritmética modular.
    Tema 4: Introducción a la teoría de grafos.
    UNIDAD TEMÁTICA 3: INTRODUCCIÓN AL CÁLCULO
    Tema 1: Funciones de una variable. Límites y continuidad.
    Tema 2: Cálculo diferencial. Aproximación local de una función.
    Tema 3: Cálculo integral. Algunas aplicaciones de la integral.
    Tema 4: Métodos numéricos sobre funciones.
 ''']
]

DEGREE_SUBJECTS_2 = [
 ['code', '200325'],
 ['name', 'Principios de programación'],
 ['subject_type', 'Formación Básica'],
 ['num_credits', 12],
 ['period', 'Anual'],
 ['course', 1]
 ['language', 'Catalán'],
 ['content', '''
     Tema 1. Introducción a la programación
     1.1. ¿Qué es la programación?
     1.2. Anatomía de un Computador.
     1.3. Lenguajes de programación. Clasificación.
     1.4. IDE.
    Bloque 1: Programación procedural
    Tema 2. Tipos de datos fundamentales
     2.1. Tipos y variables.
     2.2. Variables y constantes.
     2.3. Operadores básicos.
    Tema 3. Estructuras de control
     3.1. Algoritmos. 3.2. Estructura Secuencial.
     3.3. Estructuras de Selección.
     3.4. Estructuras iterativas o repetitivas.
    Tema 4. Tipo de datos compuestos
     4.1. Tipos de datos compuestos.
     4.2. Tratamiento de cadenas de texto.
    Tema 5. Programación modular
     5.1. Subprogramas. Procedimientos y funciones.
     5.2. Definición, llamada y declaración de funciones.
     5.3. Tipos de argumentos
    Tema 6. Estructuras de datos dinámicas
     6.1. Ficheros.
     6.2. El concepto de apuntador. Operaciones con apuntadores.
    Bloque 2. Programación orientada a objetos
    Tema 7. Introducción a la programación orientada a objetos
     7.1. Objetos, clases y métodos.
     7.2. Implementación de clases.
     7.3. Repaso de las estructuras de programación básicas.
    Tema 8. Recursividad, ordenación y búsqueda
     8.1. Recursividad.
     8.2. Diseños básicos de búsqueda.
     8.3. Algoritmos de ordenación.
    Tema 9. Utilización avanzada de clases
     9.1. Estructuras de datos dinámicas: listas, pilas, colas, árboles, conjuntos y mapas.
     9.2. Herencia y polimorfismo.
     9.3. Tratamiento de excepciones
    Tema 10. Aplicaciones visuales. Flujos y ficheros.
     10.1. Interfaces gráficas de usuario.
     10.2. El patrón MVC para construir aplicaciones visuales.
     10.3. Flujos y ficheros.
 ''']
]

DEGREE_SUBJECTS_3 = [
 ['code', '200321'],
 ['name', 'Fundamentos de computadores'],
 ['subject_type', 'Formación Básica'],
 ['num_credits', 6],
 ['period', 'Primer Semestre'],
 ['course', 1]
 ['language', 'Catalán, Castellano'],
 ['content', '''
    Tema 1. El Computador Digital (Cap. 1, Cap. 4)
    1.1. Unidades funcionales
    1.2. Representación de la información
    1.3. Estructura del computador

    Tema 2. Lenguaje Máquina (Cap. 7, Cap. 8)
    2.1. Repertorio de instrucciones
    2.2. Modos de direccionamiento
    2.3. Lenguajes máquina y ensamblador.

    Tema 3. Aritmética binaria (Cap. 9.1)
    3.1. Sistemas de numeración
    3.2. Representación de números con signo
    3.3. Operaciones aritméticas y lógicas

    Tema 4. Introducción a los circuitos lógicos (Cap. 5, Cap. 6)
    4.1. Álgebra de Boole
    4.2. Circuito combinacional
    4.3. Minimización de funciones
    4.4. Circuito secuencial

    Tema 5. Entrada / Salida y comunicaciones (Cap. 9.5, Cap. 11, Cap. 12)
    5.1. Dispositivos periféricos y sus características
    5.2. Módulos de E/S
    5.3. Interrupciones y su tratamiento
    5.4. Técnicas de E/S. Transferencia programada y DMA

    Tema 6. El sistema de memoria (Cap. 10)
    6.1. Características generales
    6.2. Memoria Principal
    6.3. Memoria secundaria

    Tema 7. Software del sistema (Cap. 13.1, 13.2, 13.3, 13.4, Cap. 14.1, 14.2, 14.3)
    7.1. Componentes básicos del software del sistema
    7.2. Traducción e interpretación
    7.3. SW de comunicación y SW de aplicaciones
 ''']
]

DEGREE_SUBJECTS_4 = [
 ['code', '200320'],
 ['name', 'Fundamentos de computadores'],
 ['subject_type', 'Formación Básica'],
 ['num_credits', 6],
 ['period', 'Primer Cuatrimestre'],
 ['course', 1]
 ['language', 'Catalán, Castellano'],
 ['content', '''
    Tema 1. Ciencia, tecnología y sociedad.
    1.1. Conceptos de ciencia, tecnología, sociedad y sus relaciones.
    1.2. Impacto en la cultura de la técnica, la ciencia y la tecnología.
    1.3. Políticas públicas de ciencia y tecnología. Regulación y evaluación de la tecnología.

    Tema 2. Modelos constructivistas del cambio tecnológico.
    2.1. Modelos de cambio tecnológico.
    2.2. La imagen tradicional del cambio tecnológico.
    2.3. Modelos constructivistas y sociológicos del cambio tecnológico.

    Tema 3. Sociología industrial.
    3.1. El concepto de sociedad industrial.
    3.2. Los efectos sociales de la industrialización. Sostenibilidad.
    3.3. Regulación y protección industrial.

    Tema 4. Sociología de las organizaciones
    4.1. Cambio de las organizaciones. El cambio como motor del desarrollo de la organización.
    4.2. El Desarrollo Organizacional como respuesta al cambio.
    4.3. El poder de las organizaciones.

    Tema 5. Bases para la gestión de las relaciones interpersonales.
    5.1. Comunicación.
    5.2. Liderazgo.
    5.3. Participación.
    5.4. Dinámica de grupos.
    5.5. Toma de decisiones.
    5.6. Resolución de conflictos.

    Tema 6. Sociología de Internet.
    6.1. Aspectos teóricos del estudio sociológico de Internet.
    6.2. Repercusiones sociales.
    6.3. Los derechos fundamentales en Internet.
    6.4. Análisis de los servicios que se prestan a través de Internet.

    Tema 7. Redes sociales.
    7.1. Análisis de los aspectos más relevantes y problemática específica de las redes sociales.
    7.2. Caracterización de las redes sociales.
    7.3. Tipología de las redes sociales.
    7.4. Riesgos de las redes sociales.
 ''']
]


DEGREE_SUBJECTS_5 = [
 ['code', '200318'],
 ['name', 'Empresa: modelos clásicos de negocio'],
 ['subject_type', 'Formación Básica'],
 ['num_credits', 6],
 ['period', 'Primer Cuatrimestre'],
 ['course', 1]
 ['language', 'Catalán, Castellano'],
 ['content', '''
    Tema 1. LA EMPRESA Y EL EMPRESARIO.
    1.1. Introducción. Principios de la Economía de la Empresa. Concepto de “Management”.
    1.2. La Empresa: Misión, Visión y Valores. Definición de objetivos empresariales.
    1.3. El Empresario: Manager vs Líder. Competencias del Manager. Auto-descubrimiento.
    1.4. Retos de futuro. La globalización.

    Tema 2. LA DIRECCIÓN ESTRATÉGICA; LA FORMULACIÓN DE LA ESTRATEGIA.
    2.1. Creación de Valor. Modelo de Negocio. Estrategia competitiva. Modelo organizativo.
    2.2. Ventaja Competitiva.
    2.3. Modelos estratégicos: estrategias genéricas de Porter, matriz de crecimiento del BCG, Mapas
    estratégicos.

    Tema 3. LA RESPONSABILIDAD SOCIAL CORPORATIVA (RSC).
    3.1. Introducción.
    3.2. Los stakeholders y su gestión.
    3.3. RSC como ventaja competitiva.

    Tema 4. TAMAÑO Y CRECIMIENTO EMPRESARIAL.
    4.1. Dimensión: decisiones sobre tamaño.
    4.2. Estrategias de crecimiento: expansión vs diversificación.
    4.3. Estrategias de expansión global.
 ''']
]

DEGREE_SUBJECTS_6 = [
 ['code', '200319'],
 ['name', 'Fundamentos físicos y tecnológicos de la informática'],
 ['subject_type', 'Formación Básica'],
 ['num_credits', 6],
 ['period', 'Segundo Cuatrimestre'],
 ['course', 1]
 ['language', 'Catalán, Castellano'],
 ['content', '''
    Tema 1. Fundamentos físicos y tecnológicos de la informática
       1.1. Introducción
    Tema 2. Electricidad y electromagnetismo
       2.1. Campo eléctrico
       2.2. Circuitos de corriente continua
       2.3. Circuitos de corriente alterna
       2.4. Principios de electromagnetismo y su papel en la comunicación
    Tema 3. Electrotecnia.
       3.1. Máquinas eléctricas: Generadores, transformadores y motores.
       3.2. Medidas electrotécnicas.
            3.2.1. Concepto de medida y Errores en la medida.
            3.2.2. Medida de magnitudes eléctricas en CC y en CA monofásica y trifásica.
                      Procedimientos.
    Tema 4. Principios de la electrónica.
       4.1. Semiconductores. Dispositivos electrónicos semiconductores.
       4.2. Componentes electrónicos semiconductores: Diodos, transistores, tiristores y
             componentes optoelectrónicos.
       4.3. Transistores:
            4.3.1. El transistor bipolar
            4.3.2. El transistor MOS
            4.3.3. Transistores en conmutación
       4.4. El amplificador operacional: montajes básicos.
    Tema 5. La electrónica digital.
       5.1. Especificaciones eléctricas de las puertas lógicas.
       5.2. Conversión digital- analógica
       5.3. Conversión analógica -digital
    Tema 6. Familias lógicas y sus características.
       6.1. Puertas lógicas. Familias
       6.2. El circuito biestable
    Tema 7. Análisis de circuitos.
       7.1. Circuitos prácticos de laboratorio: Circuitos de reloj, reset, …
       7.2. Memorias RAM, ROM, Flash: Tipos.
            7.2.1. Características físicas: volatilidad, capacidad, velocidad de acceso, densidad de
                      información. Ventajas y Limitaciones.
    Tema 8. Magnetismo y su aplicación a los sistemas de almacenamiento.
            8.1.      Discos duros y flexibles. Parámetros físicos: capacidad, velocidad de acceso, tamaño
                      de grano y densidad de información.
            8.2.      Proceso de lectura/escritura en los discos duros: inducción y magnetorresistencia.
    Tema 9. Aplicaciones de la óptica: almacenamiento, transmisión, captura y visualización de
            información.
            9.1.      Fundamentos del láser
            9.2.      Fotodiodos y diodos láser.
            9.3.      Estructura física de los discos ópticos. Codificación, capacidad, velocidad de acceso,
                      densidad de información. Almacenamiento magnetoóptico
            9.4.      Fibra óptica: transmisión de la información
 ''']
]

DEGREE_SUBJECTS_7 = [
 ['code', '200320'],
 ['name', ''],
 ['subject_type', 'Formación Básica'],
 ['num_credits', 6],
 ['period', 'Segundo Cuatrimestre'],
 ['course', 1]
 ['language', 'Inglés, Catalán, Castellano'],
 ['content', '''
    PARTE I:
    Tema 1: EL ROL CAMBIANTE DEL NUEVO CONSUMIDOR
    1.1. Características y retos de la "Net Gen” (Generación Digital) .
    1.2. Acceso a la información, Visión global, Networking, Experimentación, Activismo y co-creación
    de valor.

    Tema 2: LA TRANSFORMACIÓN DEL CONCEPTO DE MERCADO Y DE MARKETING
    2.1. El nuevo concepto de mercado.
    2.2. ¿Cómo la Web ha cambiado las reglas del Marketing y las relaciones públicas?.
    2.3. Internet: WEB 1.0, WEB 2.0 y WEB 3.0.
    2.4. La teoría de "The Long Tail".
    2.5. Tendencias a nivel mundial.

    Tema 3: LOS NUEVOS MODELOS DE NEGOCIO
    3.1. E-Business Models más desarrollados: Online retail, Advertising supported, Subscription
    model, Download fees, Affiliate marketing, Software as a Service (SaaS), Brokerage or
    Intermediary y Hybrid e-business models.
    3.2. Five-steps Action Plan for Web 2.0 Business Models:
    3.2.1. Build on collective user value.
    3.2.2. Activate network effects.
    3.2.3. Work through social networks.
    3.2.4. Dynamically syndicate competence.
    3.2.5. Recombine innovations.
    3.3. Rules for creating successful online and mobile Business Models:
    3.1. The 1st law of entrepreneurship.
    3.2. Using boosters.
    3.3. Formulating the problem.
    3.4. Hiring corporate achievers to run the company.

    Tema 4: PLAN DE NEGOCIO WEB 2.0
    I. Executive Summary.
    II. Background, business concept, objective and funding requirements.
    III. Market analysis.
    IV. Products and services.
    V. Timing and milestones.
    VI. Management and executive team.
    VII. Governance, ownership and control.
    VIII. Financials.

    PARTE II:

    Tema 5: EMPRENDEDURIA. INNOVACIÓN. LA IDEA DE NEGOCIO
    5.1. El impacto de la estrategia digital. Management emprendedor. Creatividad.
    5.2. Particularidades, tendencias y oportunidades en el ecosistema digital.
    5.3. Ideas para mi negocio en Internet: Elevator Pitch.
    5.4. Plan de Empresa para mi proyecto Web. Estructura y contenidos.
    5.5. El proceso de creación de productos digitales: innovación continua.


    Tema 6: DISEÑO DE LA PROPUESTA DE VALOR
    6.1. Del problema a la solución pasando del producto mínimo viable (PMV).
    6.2. Herramientas de conocimiento: Círculo de oro, DAFO. Ad-Libs, Lienzo Estratégico, Customer
    Insights, Mapa de Empatía.
    6.3. Lienzo de la propuesta de valor: perfil del cliente, el mapa de valor, encaje.
    6.4. Viabilidad de la propuesta de valor: la solución.
    6.5. Como validar tu PMV.

    Tema 7: MODELOS DE NEGOCIO
    7.1. Configuración del modelo de negocio: Business Model Canvas versus Lean Canvas.
    7.2. Patrones de modelos de negocio.
    7.3. Internet de las cosas: innovación en modelos de negocio.
    7.4. La economía colaborativa.
    7.5. Casos de éxito

    Tema 8: EL PLAN DE MARKETING DIGITAL
    8.1. El negocio de la atención, Always on: La omnicanalidad y el multitasking.
    8.2. El proceso de decisión de compra del consumidor digital.
    8.3. Marketing de resultados: captar, convertir, fidelizar.
    8.4. Marketing predictivo: El superconsumidor.
    8.5. Marketing de contenidos: storytelling.
    8.6. Inbound Marketing: Branded Content. Native Advertising. Brand Journalism.
    8.7. Las redes sociales y la distribución del contenido: Facebook, Twitter, YouTube, Linkedin,
    Google+, Instagram, Pinterest.
    8.8. Los formatos más populares: Blogs, Newsletters, White Papers, Ebooks, Webinars, Video,
    Podcasts.
    8.9. Casos de éxito.
 ''']
]


DEGREE_SUBJECTS_8 = [
 ['code', '200323'],
 ['name', 'Interacción persona-ordenador'],
 ['subject_type', 'Ingeniería del software'],
 ['num_credits', 6],
 ['period', 'Segundo Cuatrimestre'],
 ['course', 1]
 ['language', 'Inglés, Catalán, Castellano'],
 ['content', '''
    Tema 1. Introducción a la IPO.
    1.1. Conceptos básicos relacionados con la IPO. Ámbitos de aplicación. Estado de la IPO.
    1.2. Interfaces. Clasificación. Conceptos sobre visibilidad y affordance.
    1.3. Usabilidad. Principios heurísticos de la Usabilidad. Evaluación heurística de la Usabilidad.
    1.4. Introducción a la Accesibilidad. Tipo de discapacidades. Importancia del diseño accesible.
    Diseño Universal.
    Tema 2. Estilos de interacción y Paradigmas de computación.
    2.1. Estilos de interacción.
    2.1.1. Líneas de órdenes, Menús y Formularios, Manipulación Directa e Interacción Asistida.
    2.1.2. Estilos de vanguardia: Interacción Gestual, Brain Computer Interaction y
    Multimodalidad.
    2.2. Paradigmas de computación
    2.2.1. Ordenador de sobremesa.
    2.2.2. Computación Ubicua.
    2.2.3. Realidad Aumentada.
    2.2.4. Realidad Virtual.
    Tema 3. Antropología y sociología.
    3.1. Comportamiento humano. Orígenes y naturaleza.
    3.1.1. Conocimiento genético.
    3.1.2. Conocimiento individual.
    3.1.3. Conocimiento cultural.
    3.2. Teoría sobre las Actividades humanas.
    3.2.1. Estructura de las Actividades humanas.
    3.2.2. Mediación social y cultural.
    3.2.3. Coevolución entre conocimiento y cultura.
    3.3 Introducción a la etnografía.
    3.3.1. Diversidad cultural
    3.3.2. Conocimiento etnográfico.
    3.3.3. El proceso etnográfico. Descripción densa. Estudios de campo.
    3.3.4. Internacionalización y localización de sistemas de computación.

    Tema 4. Factores humanos.
    4.1. Psicología cognitiva.
    4.1.1. Procesamiento de la información.
    4.1.2. Canales sensoriales y percepción.
    4.1.3. Memoria Sensorial, de Trabajo y de Largo Plazo.
    4.2. Carga cognitiva.
    4.2.1. Carga Intrínseca, Extraña y Hermana.
    4.2.2. Soluciones a la sobrecarga cognitiva.
    4.3. Psicología emocional.
    4.3.1. ¿Qué es una emoción? Clasificación. Dimensiones de las emociones. Origen de las
    emociones. Comportamiento humano y emociones.
    4.3.2. Emoción, Motivación y Comportamiento.
 ''']
]

DEGREE_SUBJECTS_9 = [
 ['code', '200322'],
 ['name', '],
 ['subject_type', 'Ingeniería del software'],
 ['num_credits', 6],
 ['period', 'Primer Cuatrimestre'],
 ['course', 2]
 ['language', 'Catalán, Castellano'],
 ['content', '''
 ''']
]
