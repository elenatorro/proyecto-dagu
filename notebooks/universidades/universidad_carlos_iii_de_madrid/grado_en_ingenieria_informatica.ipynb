# %%
DEGREE_NAME = 'grado_en_ingenieria_informatica'
UNIVERSITY_NAME = 'universidad_carlos_iii_de_madrid'
DEGREE_CODE = 218
SUBJECT_COLUMNS = ['code', 'degree_code', 'name', 'subject_type', 'num_credits', 'period', 'course', 'language', 'content', 'mention', 'url', 'bibliography']

# %%
DEGREE_COLUMNS = ['code',
'university',
'name',
'summary',
'area',
'years',
'num_credits',
'num_places',
'faculty',
'url',
'price_1',
'price_2',
'price_3',
'price_4',
'total_min_price',
'admission_mark',
'profile',
'opportunities',
'learning_mode',
'mobility_program',
'working_practices',
'basic_skills',
'specific_skills',
'transversal_skills',
'double_degree',
'schedule',
'subjects',
'languages',
'mentions'
]

# %%
DEGREE_DATA = {
    'code': DEGREE_CODE,
    'university': 'Universidad Carlos III de Madrid',
    'name': 'Grado en Ingeniería Informática',
    'summary': '''
        El Grado en Ingeniería Informática tiene como objetivo la formación en un conjunto de conocimientos científicos y técnicos que hacen posible la adquisición, representación, tratamiento y transmisión de la información por medio de computadoras.
        El plan de estudios permite profundizar en distintos ámbitos: la Computación orientada a la Inteligencia Artificial; la Ingeniería de Computadoras dirigida al desarrollo de hardware y software distribuido; y los Sistemas de Información referidos al tratamiento de datos e integración del software empresarial. Puede cursarse en modalidad bilingüe y cuenta con el sello EUR-ACE.
        Este grado ofrece una sólida formación en materias básicas como matemáticas o estadística; así como en materias tecnológicas como I.A., ingeniería del software, ciberseguridad o sistemas operativos, entre otras. Se trata de una titulación muy demandada por las empresas con una tasa de empleabilidad del 100%.
    ''',
    'area': 'Campus de Leganés, Campus de Colmenarejo',
    'years': 4,
    'num_credits': 240,
    'num_places': 200,
    'faculty': 'Escuela Politécnica Superior',
    'url': '',
    'price_1': 24.55,
    'price_2': 45.25,
    'price_3': 92.86,
    'price_4': 128.57,
    'total_min_price': 240 * 24.55,
    'admission_mark': 7.990,
    'profile': '''
        El perfil del egresado del Grado en Ingeniería Informática se configura con los resultados del aprendizaje obtenidos en este Grado, que incluyen, en primer lugar, los conocimientos y la comprensión de los fundamentos básicos generales de la ingeniería, así como en particular, los de los Ingeniería Informática. Los egresados serán capaces de llevar a cabo un proceso de análisis para resolver problemas de informática y además, serán competentes para realizar diseños de ingeniería en su ámbito, trabajando en equipo. Asimismo, los titulados serán capaces de realizar investigación y llevar a cabo aportaciones innovadores en los sistemas informáticos, lo que justifica el interés científico de este Grado, que se aborda después.
        Finalmente, los egresados serán competentes para aplicar sus conocimientos para resolver problemas y diseñar productos, servicios y sistemas informáticos las implicaciones medio ambientales, comerciales, de seguridad e industriales que tiene la práctica de la ingeniería; Además, de la formación puramente técnica, el egresado habrá recibido formación en destrezas de comunicación, humanidades e idiomas, lo que reforzará sus aspectos competitivos a nivel de comunicación personal y de eficiencia de transmisión de sus conocimientos y facilidad de inserción en equipos nacionales e internacionales
    ''',
    'opportunities': '',
    'learning_mode': 'Presencial',
    'mobility_program': '''
        El programa Erasmus permite a estudiantes de la UC3M de Grado y Postgrado, cursar uno o varios cuatrimestres en una de las universidades europeas con las que la UC3M tiene acuerdos o realizar un Erasmus Placement, es decir, una estancia en prácticas en alguna empresa de la UE. Estos intercambios cuentan con dotación económica  gracias a las Becas Erasmus que proporcionan la UE y el Ministerio de Educación español.
        Por su parte, el programa de Movilidad No Europea permite a los estudiantes de Grado de la UC3M cursar uno o varios cuatrimestres en una de las universidades internacionales con las que la universidad mantiene acuerdos. Además cuenta con dotación económica  proporcionada por el Banco Santander y la UC3M.
        En ambos casos, las plazas se ofrecen en convocatoria pública y son adjudicadas a los estudiantes con mejor expediente que han superado el umbral de idioma (inglés, francés, alemán…) exigido por la universidad socia.
    ''',
    'working_practices': '''
        Están incluidas en los planes de estudio como asignatura obligatoria u optativa que, en la mayoría de los casos, podrá matricularse de forma ordinaria o extraordinaria.
        Su duración vendrá determinada en función de los créditos que contempla el plan de estudios.
        Podrán realizarse a lo largo de todo el curso, incluidos los periodos no lectivos.
    ''',
    'basic_skills': '''
    ''',
    'specific_skills': '''
    ''',
    'transversal_skills': '''
    ''',
    'double_degree': False,
    'schedule': 'Mañana y tarde',
    'subjects': '',
    'languages': 'Español, Inglés',
    'mentions': '''
        Computación, Ingeniería de Computadores y Sistemas de Información.
    '''
}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

SUBJECT_TYPE = {
    'FB': 'Formación Básica',
    'O': 'Obligatoria',
    'P': 'Optativa',
    'O-P': 'Optativa, Obligatoria',
    'TFG': 'Trabajo Fin de Grado'
}

subjects_list = []

# %%
degree_df = pd.DataFrame([DEGREE_DATA], columns=DEGREE_COLUMNS)
degree_df.to_csv('{}.csv'.format(DEGREE_NAME),  index=False)

# %%
def get_subject(url):
    page = requests.get(url, verify=False)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    name = soup.select('.asignatura')[0].getText(strip=True)
    code = soup.select('.asignatura')[1].getText().replace('(', '').replace(')', '')
    subject_type = soup.select('.container-fluid > div > .col.izquierda')[0].getText(strip=True).replace('Tipo:', '')
    num_credits = float(soup.select('.container-fluid > div > .col.izquierda')[1].getText(strip=True).replace('Créditos:', '').replace('ECTS', ''))

    period = 0
    course = 0

    try:
        course_str = soup.select('.container-fluid > div > .col.izquierda')[2].getText(strip=True)
        course = int(course_str.replace('Curso:', '').replace('º', ''))
    except ValueError:
        print('course')
        print(course_str)

    try:
        period_str = soup.select('.container-fluid > div > .col.izquierda')[3].getText(strip=True)
        period = period_str.replace('Cuatrimestre:', '').replace('º', '')

        if period:
            period = int(period)

    except ValueError:
        print('period')
        print(period_str)

    languages = [] # TODO
    language = 'Español'

    panels = soup.select('.panel-heading')
    panels_body = soup.select('.panel-body')
    bibliography = ''
    content = ''

    for i in range(len(panels)):
        panel_text = panels[i].getText()
        if 'Bibliografía' in panel_text:
            bibliography = panel_text.encode()
        elif 'contenidos' in panel_text:
            content = panel_text.encode()
    
    subject_data = {
     'code': code,
     'degree_code': DEGREE_CODE,
     'name': name,
     'subject_type': subject_type,
     'num_credits': num_credits,
     'period': period,
     'course': course,
     'language': language,
     'content': content,
     'mention': '',
     'url': url,
     'bibliography': bibliography
    }
    
    subjects_list.append(subject_data)

# %%
def get_subjects(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')

    subjects = soup.select('td[data-label="Asignatura"] > a')

    for subject in subjects:
        subject_url = subject.get('href')
        name = subject.getText(strip=True)

        if 'Habilidades' not in name:
            get_subject(subject_url)

# %%
url = 'https://www.uc3m.es/grado/informatica#programa'

get_subjects(url)
# Out:
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ...
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# course
# Curso:XXº
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# course
# Curso:XXº
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# /Users/elenatorro/.local/share/virtualenvs/unknowniversity-5YM2mFLK/lib/python3.7/site-packages/urllib3/connectionpool.py:986: InsecureRequestWarning: Unverified HTTPS request is being made to host 'aplicaciones.uc3m.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# course
# Curso:XXº

# %%
subjects_list
# Out:
# [{'code': '13866',
#   'degree_code': 218,
#   'name': 'Cálculo',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13866&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13867',
#   'degree_code': 218,
#   'name': 'Física',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13867&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13868',
#   'degree_code': 218,
#   'name': 'Programación',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13868&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13870',
#   'degree_code': 218,
#   'name': 'Álgebra Lineal',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13870&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '14360',
#   'degree_code': 218,
#   'name': 'Técnicas de expresión oral y escrita',
#   'subject_type': 'Obligatoria',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=14360&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13869',
#   'degree_code': 218,
#   'name': 'Tecnología de Computadores',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13869&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13873',
#   'degree_code': 218,
#   'name': 'Estructura de datos y algoritmos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13873&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15969',
#   'degree_code': 218,
#   'name': 'Principios físicos de la ingeniería informática',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15969&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15970',
#   'degree_code': 218,
#   'name': 'Lógica',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15970&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15971',
#   'degree_code': 218,
#   'name': 'Matemática Discreta',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15971&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13874',
#   'degree_code': 218,
#   'name': 'Estructura de Computadores',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13874&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13875',
#   'degree_code': 218,
#   'name': 'Fundamentos de gestión empresarial',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13875&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13876',
#   'degree_code': 218,
#   'name': 'Estadística',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13876&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13877',
#   'degree_code': 218,
#   'name': 'Teoría de autómatas y lenguajes formales',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13877&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15974',
#   'degree_code': 218,
#   'name': 'Ingeniería del Software',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15974&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13878',
#   'degree_code': 218,
#   'name': 'Sistemas Operativos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13878&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13881',
#   'degree_code': 218,
#   'name': 'Ficheros y bases de datos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13881&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13883',
#   'degree_code': 218,
#   'name': 'Inteligencia Artificial',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13883&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15975',
#   'degree_code': 218,
#   'name': 'Cálculo diferencial aplicado',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15975&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '18179',
#   'degree_code': 218,
#   'name': 'Desarrollo de Software',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18179&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13882',
#   'degree_code': 218,
#   'name': 'Interfaces de Usuario',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13882&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13884',
#   'degree_code': 218,
#   'name': 'Redes de ordenadores',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13884&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13888',
#   'degree_code': 218,
#   'name': 'Arquitectura de computadores',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13888&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15973',
#   'degree_code': 218,
#   'name': 'Criptografía y seguridad informática',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15973&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15976',
#   'degree_code': 218,
#   'name': 'Heurística y Optimización',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15976&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13889',
#   'degree_code': 218,
#   'name': 'Diseño de sistemas operativos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13889&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13890',
#   'degree_code': 218,
#   'name': 'Procesadores del Lenguaje',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13890&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13891',
#   'degree_code': 218,
#   'name': 'Diseño de sistemas interactivos',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13891&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '14155',
#   'degree_code': 218,
#   'name': 'Técnicas de búsqueda y uso de la información',
#   'subject_type': 'Obligatoria',
#   'num_credits': 1.5,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=14155&idioma=1',
#   'bibliography': ''},
#  {'code': '15757',
#   'degree_code': 218,
#   'name': 'Aprendizaje Automático',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15757&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '17881',
#   'degree_code': 218,
#   'name': 'Hojas de cálculo. Nivel avanzado',
#   'subject_type': 'Sin tipo definido',
#   'num_credits': 1.5,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=17881&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13885',
#   'degree_code': 218,
#   'name': 'Organización de Computadores',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13885&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13889',
#   'degree_code': 218,
#   'name': 'Diseño de sistemas operativos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13889&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '14155',
#   'degree_code': 218,
#   'name': 'Técnicas de búsqueda y uso de la información',
#   'subject_type': 'Obligatoria',
#   'num_credits': 1.5,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=14155&idioma=1',
#   'bibliography': ''},
#  {'code': '15754',
#   'degree_code': 218,
#   'name': 'Sistemas Distribuidos',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15754&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '17881',
#   'degree_code': 218,
#   'name': 'Hojas de cálculo. Nivel avanzado',
#   'subject_type': 'Sin tipo definido',
#   'num_credits': 1.5,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=17881&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '18200',
#   'degree_code': 218,
#   'name': 'Ingeniería de la ciberseguridad aplicada a los sistemas de información',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18200&idioma=1',
#   'bibliography': ''},
#  {'code': '13889',
#   'degree_code': 218,
#   'name': 'Diseño de sistemas operativos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13889&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '14155',
#   'degree_code': 218,
#   'name': 'Técnicas de búsqueda y uso de la información',
#   'subject_type': 'Obligatoria',
#   'num_credits': 1.5,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=14155&idioma=1',
#   'bibliography': ''},
#  {'code': '17881',
#   'degree_code': 218,
#   'name': 'Hojas de cálculo. Nivel avanzado',
#   'subject_type': 'Sin tipo definido',
#   'num_credits': 1.5,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=17881&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '18200',
#   'degree_code': 218,
#   'name': 'Ingeniería de la ciberseguridad aplicada a los sistemas de información',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18200&idioma=1',
#   'bibliography': ''},
#  {'code': '18203',
#   'degree_code': 218,
#   'name': 'Métodos y técnicas de trabajo cooperativo',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18203&idioma=1',
#   'bibliography': ''},
#  {'code': '18204',
#   'degree_code': 218,
#   'name': 'Técnicas de desarrollo de software',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18204&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13894',
#   'degree_code': 218,
#   'name': 'Ingeniería del Conocimiento',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13894&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13898',
#   'degree_code': 218,
#   'name': 'Redes de neuronas artificiales',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13898&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15764',
#   'degree_code': 218,
#   'name': 'Inteligencia artificial en las organizaciones',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15764&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15756',
#   'degree_code': 218,
#   'name': 'Tecnologías informáticas para la web',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15756&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15759',
#   'degree_code': 218,
#   'name': 'Multimedia',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15759&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15762',
#   'degree_code': 218,
#   'name': 'Sistemas de tiempo real',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15762&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15753',
#   'degree_code': 218,
#   'name': 'Desarrollo de sistemas de información corporativos',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15753&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15810',
#   'degree_code': 218,
#   'name': 'Metodología de desarrollo visual',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15810&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '18205',
#   'degree_code': 218,
#   'name': 'Tecnologías informáticas para los sistemas de información en web',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18205&idioma=1',
#   'bibliography': ''},
#  {'code': '15751',
#   'degree_code': 218,
#   'name': 'Panorámica de las comunicaciones digitales',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15751&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15755',
#   'degree_code': 218,
#   'name': 'Algoritmos genéticos y evolutivos',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15755&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15986',
#   'degree_code': 218,
#   'name': 'Análisis de Datos',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15986&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15987',
#   'degree_code': 218,
#   'name': 'Inteligencia artificial en industria de entretenimiento',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15987&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15988',
#   'degree_code': 218,
#   'name': 'Prácticas Externas',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15988&idioma=1',
#   'bibliography': ''},
#  {'code': '15989',
#   'degree_code': 218,
#   'name': 'Computación Ubicua',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15989&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15990',
#   'degree_code': 218,
#   'name': 'Desarrollo de software de sistemas',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15990&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15992',
#   'degree_code': 218,
#   'name': 'Equipos Virtuales',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15992&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15993',
#   'degree_code': 218,
#   'name': 'Gestión del conocimiento organizativo',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15993&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15994',
#   'degree_code': 218,
#   'name': 'Accesibilidad y diseño para todos en ingeniería del software',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15994&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15995',
#   'degree_code': 218,
#   'name': 'Programación orientada a objetos',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15995&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '18180',
#   'degree_code': 218,
#   'name': 'Accesibilidad a los medios audiovisuales',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18180&idioma=1',
#   'bibliography': ''},
#  {'code': '18181',
#   'degree_code': 218,
#   'name': 'Algoritmos de resolución de problemas',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18181&idioma=1',
#   'bibliography': ''},
#  {'code': '18182',
#   'degree_code': 218,
#   'name': 'Almacenamiento masivo y Big Data',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18182&idioma=1',
#   'bibliography': ''},
#  {'code': '18183',
#   'degree_code': 218,
#   'name': 'Desarrollo de aplicaciones para móvil',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18183&idioma=1',
#   'bibliography': ''},
#  {'code': '18184',
#   'degree_code': 218,
#   'name': 'Desarrollo de Videojuegos',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18184&idioma=1',
#   'bibliography': ''},
#  {'code': '18187',
#   'degree_code': 218,
#   'name': 'Entornos inteligentes sensorizados: IoT (Internet de las cosas)',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18187&idioma=1',
#   'bibliography': ''},
#  {'code': '18188',
#   'degree_code': 218,
#   'name': 'Inteligencia Artificial aplicada al control de sistemas',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18188&idioma=1',
#   'bibliography': ''},
#  {'code': '18189',
#   'degree_code': 218,
#   'name': 'Minería de Textos',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18189&idioma=1',
#   'bibliography': ''},
#  {'code': '18190',
#   'degree_code': 218,
#   'name': 'Paradigmas de Programación',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18190&idioma=1',
#   'bibliography': ''},
#  {'code': '18191',
#   'degree_code': 218,
#   'name': 'Procesamiento en Big Data',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18191&idioma=1',
#   'bibliography': ''},
#  {'code': '18192',
#   'degree_code': 218,
#   'name': 'Programación para servidores web',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18192&idioma=1',
#   'bibliography': ''},
#  {'code': '18193',
#   'degree_code': 218,
#   'name': 'Sistemas inteligentes para la interacción',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18193&idioma=1',
#   'bibliography': ''},
#  {'code': '18194',
#   'degree_code': 218,
#   'name': 'Sistemas multimodales inteligentes',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18194&idioma=1',
#   'bibliography': ''},
#  {'code': '18195',
#   'degree_code': 218,
#   'name': 'Técnicas de análisis en Big Data',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18195&idioma=1',
#   'bibliography': ''},
#  {'code': '18196',
#   'degree_code': 218,
#   'name': 'Técnicas de visualización para Big Data',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18196&idioma=1',
#   'bibliography': ''},
#  {'code': '18197',
#   'degree_code': 218,
#   'name': 'Tecnologías al servicio de la discapacidad',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18197&idioma=1',
#   'bibliography': ''},
#  {'code': '18198',
#   'degree_code': 218,
#   'name': 'Tecnologías para la privacidad',
#   'subject_type': 'Optativa',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18198&idioma=1',
#   'bibliography': ''},
#  {'code': '13892',
#   'degree_code': 218,
#   'name': 'Dirección de proyectos de desarrollo de software',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13892&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13895',
#   'degree_code': 218,
#   'name': 'Trabajo Fin de Grado',
#   'subject_type': 'Trabajo fin de Grado',
#   'num_credits': 12.0,
#   'period': '',
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13895&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15763',
#   'degree_code': 218,
#   'name': 'Teoría avanzada de la computación',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15763&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '18199',
#   'degree_code': 218,
#   'name': 'Informática gráfica e inteligencia artificial',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18199&idioma=1',
#   'bibliography': ''},
#  {'code': '13892',
#   'degree_code': 218,
#   'name': 'Dirección de proyectos de desarrollo de software',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13892&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13895',
#   'degree_code': 218,
#   'name': 'Trabajo Fin de Grado',
#   'subject_type': 'Trabajo fin de Grado',
#   'num_credits': 12.0,
#   'period': '',
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13895&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '18201',
#   'degree_code': 218,
#   'name': 'Informática gráfica y aceleración hardware',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': '',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18201&idioma=1',
#   'bibliography': ''},
#  {'code': '18202',
#   'degree_code': 218,
#   'name': 'Seguridad en dispositivos y comunicaciones móviles',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=18202&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13892',
#   'degree_code': 218,
#   'name': 'Dirección de proyectos de desarrollo de software',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13892&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13895',
#   'degree_code': 218,
#   'name': 'Trabajo Fin de Grado',
#   'subject_type': 'Trabajo fin de Grado',
#   'num_credits': 12.0,
#   'period': '',
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=13895&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15760',
#   'degree_code': 218,
#   'name': 'Recuperación y acceso a la información',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15760&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15809',
#   'degree_code': 218,
#   'name': 'Diseño y administración de bases de datos',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=431&asig=15809&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13870',
#   'degree_code': 218,
#   'name': 'Álgebra Lineal',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13870&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13866',
#   'degree_code': 218,
#   'name': 'Cálculo',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13866&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13867',
#   'degree_code': 218,
#   'name': 'Física',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13867&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13868',
#   'degree_code': 218,
#   'name': 'Programación',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13868&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '14359',
#   'degree_code': 218,
#   'name': 'Técnicas de búsqueda y uso de la información',
#   'subject_type': 'Obligatoria',
#   'num_credits': 3.0,
#   'period': '',
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=14359&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '14360',
#   'degree_code': 218,
#   'name': 'Técnicas de expresión oral y escrita',
#   'subject_type': 'Obligatoria',
#   'num_credits': 3.0,
#   'period': 1,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=14360&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15971',
#   'degree_code': 218,
#   'name': 'Matemática Discreta',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15971&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15969',
#   'degree_code': 218,
#   'name': 'Principios físicos de la ingeniería informática',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15969&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13869',
#   'degree_code': 218,
#   'name': 'Tecnología de Computadores',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13869&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13873',
#   'degree_code': 218,
#   'name': 'Estructura de datos y algoritmos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13873&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15970',
#   'degree_code': 218,
#   'name': 'Lógica',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 1,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15970&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15975',
#   'degree_code': 218,
#   'name': 'Cálculo diferencial aplicado',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15975&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13876',
#   'degree_code': 218,
#   'name': 'Estadística',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13876&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13874',
#   'degree_code': 218,
#   'name': 'Estructura de Computadores',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13874&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13875',
#   'degree_code': 218,
#   'name': 'Fundamentos de gestión empresarial',
#   'subject_type': 'Formación básica',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13875&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13877',
#   'degree_code': 218,
#   'name': 'Teoría de autómatas y lenguajes formales',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13877&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15973',
#   'degree_code': 218,
#   'name': 'Criptografía y seguridad informática',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15973&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13881',
#   'degree_code': 218,
#   'name': 'Ficheros y bases de datos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13881&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13883',
#   'degree_code': 218,
#   'name': 'Inteligencia Artificial',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13883&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15972',
#   'degree_code': 218,
#   'name': 'Principios de desarrollo de software',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15972&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13878',
#   'degree_code': 218,
#   'name': 'Sistemas Operativos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 2,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13878&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13888',
#   'degree_code': 218,
#   'name': 'Arquitectura de computadores',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13888&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15976',
#   'degree_code': 218,
#   'name': 'Heurística y Optimización',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15976&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15974',
#   'degree_code': 218,
#   'name': 'Ingeniería del Software',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15974&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13882',
#   'degree_code': 218,
#   'name': 'Interfaces de Usuario',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13882&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13884',
#   'degree_code': 218,
#   'name': 'Redes de ordenadores',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
# ...
#   'name': 'Dirección de proyectos de desarrollo de software',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13892&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '13889',
#   'degree_code': 218,
#   'name': 'Diseño de sistemas operativos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13889&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13893',
#   'degree_code': 218,
#   'name': 'Ingeniería de la seguridad',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13893&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13896',
#   'degree_code': 218,
#   'name': 'Métodos y técnicas de trabajo corporativo',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13896&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15812',
#   'degree_code': 218,
#   'name': 'Técnicas ágiles de desarrollo de software',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 3,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15812&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13894',
#   'degree_code': 218,
#   'name': 'Ingeniería del Conocimiento',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13894&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15764',
#   'degree_code': 218,
#   'name': 'Inteligencia artificial en las organizaciones',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15764&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13898',
#   'degree_code': 218,
#   'name': 'Redes de neuronas artificiales',
#   'subject_type': 'Sin tipo definido',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13898&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15755',
#   'degree_code': 218,
#   'name': 'Algoritmos genéticos y evolutivos',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15755&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15986',
#   'degree_code': 218,
#   'name': 'Análisis de Datos',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15986&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15987',
#   'degree_code': 218,
#   'name': 'Inteligencia artificial en industria de entretenimiento',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15987&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15988',
#   'degree_code': 218,
#   'name': 'Prácticas Externas',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15988&idioma=1',
#   'bibliography': ''},
#  {'code': '15995',
#   'degree_code': 218,
#   'name': 'Programación orientada a objetos',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15995&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15759',
#   'degree_code': 218,
#   'name': 'Multimedia',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15759&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15762',
#   'degree_code': 218,
#   'name': 'Sistemas de tiempo real',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15762&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15756',
#   'degree_code': 218,
#   'name': 'Tecnologías informáticas para la web',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15756&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15989',
#   'degree_code': 218,
#   'name': 'Computación Ubicua',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': '',
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15989&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada b\xc3\xa1sica'},
#  {'code': '15990',
#   'degree_code': 218,
#   'name': 'Desarrollo de software de sistemas',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': '',
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15990&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15991',
#   'degree_code': 218,
#   'name': 'Informática Forense',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': '',
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15991&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15751',
#   'degree_code': 218,
#   'name': 'Panorámica de las comunicaciones digitales',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': '',
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15751&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15988',
#   'degree_code': 218,
#   'name': 'Prácticas Externas',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15988&idioma=1',
#   'bibliography': ''},
#  {'code': '15753',
#   'degree_code': 218,
#   'name': 'Desarrollo de sistemas de información corporativos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15753&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15810',
#   'degree_code': 218,
#   'name': 'Metodología de desarrollo visual',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15810&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15756',
#   'degree_code': 218,
#   'name': 'Tecnologías informáticas para la web',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15756&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15994',
#   'degree_code': 218,
#   'name': 'Accesibilidad y diseño para todos en ingeniería del software',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': '',
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15994&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15992',
#   'degree_code': 218,
#   'name': 'Equipos Virtuales',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': '',
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15992&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15993',
#   'degree_code': 218,
#   'name': 'Gestión del conocimiento organizativo',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': '',
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15993&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15988',
#   'degree_code': 218,
#   'name': 'Prácticas Externas',
#   'subject_type': 'Optativa',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15988&idioma=1',
#   'bibliography': ''},
#  {'code': '13898',
#   'degree_code': 218,
#   'name': 'Redes de neuronas artificiales',
#   'subject_type': 'Sin tipo definido',
#   'num_credits': 6.0,
#   'period': 1,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13898&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15758',
#   'degree_code': 218,
#   'name': 'Informática Gráfica',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15758&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15763',
#   'degree_code': 218,
#   'name': 'Teoría avanzada de la computación',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15763&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13895',
#   'degree_code': 218,
#   'name': 'Trabajo Fin de Grado',
#   'subject_type': 'Trabajo fin de Grado',
#   'num_credits': 12.0,
#   'period': '',
#   'course': 0,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13895&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15758',
#   'degree_code': 218,
#   'name': 'Informática Gráfica',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15758&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15761',
#   'degree_code': 218,
#   'name': 'Seguridad en dispositivos móviles',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15761&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13895',
#   'degree_code': 218,
#   'name': 'Trabajo Fin de Grado',
#   'subject_type': 'Trabajo fin de Grado',
#   'num_credits': 12.0,
#   'period': '',
#   'course': 0,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13895&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15809',
#   'degree_code': 218,
#   'name': 'Diseño y administración de bases de datos',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15809&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '15760',
#   'degree_code': 218,
#   'name': 'Recuperación y acceso a la información',
#   'subject_type': 'Obligatoria',
#   'num_credits': 6.0,
#   'period': 2,
#   'course': 4,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=15760&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'},
#  {'code': '13895',
#   'degree_code': 218,
#   'name': 'Trabajo Fin de Grado',
#   'subject_type': 'Trabajo fin de Grado',
#   'num_credits': 12.0,
#   'period': '',
#   'course': 0,
#   'language': 'Español',
#   'content': b'Descripci\xc3\xb3n de contenidos: Programa',
#   'mention': '',
#   'url': 'https://aplicaciones.uc3m.es/cpa/generaFicha?est=218&plan=256&asig=13895&idioma=1',
#   'bibliography': b'Bibliograf\xc3\xada complementaria'}]

# %%
SUBJECT_COLUMNS = ['code', 'name', 'subject_type', 'num_credits', 'period', 'course', 'language', 'content', 'mention', 'url', 'bibliography']

# %%
df = pd.DataFrame(subjects_list, columns=SUBJECT_COLUMNS)

# %%
df.head()
# Out:
#     code                                  name      subject_type  num_credits  \
# 0  13866                               Cálculo  Formación básica          6.0
# 1  13867                                Física  Formación básica          6.0
# 2  13868                          Programación  Formación básica          6.0
# 3  13870                        Álgebra Lineal  Formación básica          6.0
# 4  14360  Técnicas de expresión oral y escrita       Obligatoria          3.0
#
#   period  course language                                        content  \
# 0      1       1  Español  b'Descripci\xc3\xb3n de contenidos: Programa'
# 1      1       1  Español  b'Descripci\xc3\xb3n de contenidos: Programa'
# 2      1       1  Español  b'Descripci\xc3\xb3n de contenidos: Programa'
# 3      1       1  Español  b'Descripci\xc3\xb3n de contenidos: Programa'
# 4      1       1  Español  b'Descripci\xc3\xb3n de contenidos: Programa'
#
#   mention                                                url  \
# 0          https://aplicaciones.uc3m.es/cpa/generaFicha?e...
# 1          https://aplicaciones.uc3m.es/cpa/generaFicha?e...
# 2          https://aplicaciones.uc3m.es/cpa/generaFicha?e...
# 3          https://aplicaciones.uc3m.es/cpa/generaFicha?e...
# 4          https://aplicaciones.uc3m.es/cpa/generaFicha?e...
#
#                             bibliography
# 0  b'Bibliograf\xc3\xada complementaria'
# 1  b'Bibliograf\xc3\xada complementaria'
# 2   b'Bibliograf\xc3\xada b\xc3\xa1sica'
# 3  b'Bibliograf\xc3\xada complementaria'
# 4  b'Bibliograf\xc3\xada complementaria'

# %%
df.to_csv('{}_subjects.csv'.format(DEGREE_NAME),  index=False)

# %%
df.tail()
# Out:
#       code                                       name          subject_type  \
# 171  15761          Seguridad en dispositivos móviles           Obligatoria
# 172  13895                       Trabajo Fin de Grado  Trabajo fin de Grado
# 173  15809  Diseño y administración de bases de datos           Obligatoria
# 174  15760     Recuperación y acceso a la información           Obligatoria
# 175  13895                       Trabajo Fin de Grado  Trabajo fin de Grado
#
#      num_credits period  course language  \
# 171          6.0      2       4  Español
# 172         12.0              0  Español
# 173          6.0      2       4  Español
# 174          6.0      2       4  Español
# 175         12.0              0  Español
#
#                                            content mention  \
# 171  b'Descripci\xc3\xb3n de contenidos: Programa'
# 172  b'Descripci\xc3\xb3n de contenidos: Programa'
# 173  b'Descripci\xc3\xb3n de contenidos: Programa'
# 174  b'Descripci\xc3\xb3n de contenidos: Programa'
# 175  b'Descripci\xc3\xb3n de contenidos: Programa'
#
#                                                    url  \
# 171  https://aplicaciones.uc3m.es/cpa/generaFicha?e...
# 172  https://aplicaciones.uc3m.es/cpa/generaFicha?e...
# 173  https://aplicaciones.uc3m.es/cpa/generaFicha?e...
# 174  https://aplicaciones.uc3m.es/cpa/generaFicha?e...
# 175  https://aplicaciones.uc3m.es/cpa/generaFicha?e...
#
#                               bibliography
# 171  b'Bibliograf\xc3\xada complementaria'
# 172  b'Bibliograf\xc3\xada complementaria'
# 173  b'Bibliograf\xc3\xada complementaria'
# 174  b'Bibliograf\xc3\xada complementaria'
# 175  b'Bibliograf\xc3\xada complementaria'
