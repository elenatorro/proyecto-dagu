# %%
DEGREE_NAME = 'grado_en_ingenieria_de_datos'
UNIVERSITY_NAME = ''

# %%
DEGREE_COLUMNS = ['code',
'university',
'name',
'summary',
'area',
'years',
'num_credits',
'num_places',
'faculty',
'url',
'price_1',
'price_2',
'price_3',
'price_4',
'total_min_price',
'admission_mark',
'profile',
'opportunities',
'learning_mode',
'mobility_program',
'working_practices',
'basic_skills',
'specific_skills',
'transversal_skills',
'double_degree',
'schedule',
'subjects',
'languages',
'mentions'
]

# %%
DEGREE_DATA=DEGREE_DATA = {
    'code': 0,
    'university': UNIVERSITY_NAME,
    'name': DEGREE_NAME,
    'summary': '''
    ''',
    'area': '',
    'years': 4,
    'num_credits': 240,
    'num_places': 90,
    'faculty': '',
    'url': 'https://www.uji.es/estudis/oferta/base/graus/actual/informatica/?urlRedirect=https://www.uji.es/estudis/oferta/base/graus/actual/informatica/&url=/estudis/oferta/base/graus/actual/informatica/',
    'price_1': 0,
    'price_2': 0,
    'price_3': 0,
    'price_4': 0,
    'total_min_price': 240 * 0,
    'admission_mark': 7.436,
    'profile': '''
        Aun no existiendo pruebas de acceso especiales, el perfil de ingreso recomendado de los estudiantes que quieran acceder a este grado es de personas a las que les gusten las nuevas tecnologías de la información y las comunicaciones, con capacidad de trabajo en equipo y de analizar y resolver problemas. En general, tienen una formación adecuada aquellas personas que han cursado el bachillerato de la modalidad Científico-Tecnológico.
    ''',
    'opportunities': '''
        Ámbitos de trabajo

        El mercado de trabajo demanda una gran cantidad de profesionales del ámbito de la Ingeniería Informática, por lo tanto hay muchas posibilidades de trabajo y una tasa mucha baja de paro. Algunas de las salidas profesionales existentes son:

        Dirección de informática y departamentos de desarrollo.
        Dirección y organización de proyectos informáticos de toda índole.
        Dirección de centros de programación.
        Organización y mantenimiento de infraestructuras.
        Arquitectura, dirección y diseño de sistemas informáticos.
        Asistencia técnica de sistemas informáticos, bases de datos, y comunicaciones.
        Análisis, consultoría y auditoría informática.
        Inteligencia artificial y nuevas tecnologías.
        Diseño, selección y evaluación de infraestructura de computación y lógica.
        Dirección, gestión y optimización de sistemas de comunicación entre los ordenadores y los usuarios.
        Concepción de proyectos y aplicaciones para su posterior análisis y ejecución.
        Docencia en todos los niveles académicos.
        Investigación, formación, docencia, técnicos comerciales y puestos de dirección en cualquier área empresarial.
        Tareas profesionales

        Ejercer la dirección y ser responsable de proyectos informáticos.
        Analizar y programar aplicaciones informáticas
        Integrarse en equipos de desarrollo de software
        Diseñar, seleccionar, mantener y evaluar infraestructuras de computación.
        Aplicar sistemas especializados en redes de teleprocesos.
        Diseñar, construir y gestionar sistemas de información y herramientas de gestión para la pequeña y mediana empresa.
        Abrir empresas en Internet.
        Ejercer de jefe y técnico de sistemas.
        Gestionar sistemas de información abiertos en la red.
        Realizar el mantenimiento de aplicaciones y sistemas de información.
        Diseñar sistemas de bases de datos, de comunicación o de seguridad informática.
        Consultoría técnica en informática.
        Auditorías informáticas.
        Enseñar y formar en temas relacionados con la informática.
        Ejercer la dirección y ser responsable de proyectos.
    '''
    'learning_mode': 'Presencial',
    'mobility_program': '''
Movilidad en universidades extranjeras

PROGRAMA ERASMUS+

El programa Erasmus+ contempla la movilidad del estudiantado que cursa los últimos años de los estudios de grado con el fin de ofrecer una experiencia de aprendizaje en Europa. Las estancias pueden tener una duración desde un semestre hasta un curso académico , con las finalidades siguientes:

Fomentar la adquisición de competencias (conocimientos, habilidades y aptitudes) del estudiantado, para la mejora de su desarrollo personal y empleabilidad.
Contribuir a la creación de una comunidad de jóvenes y futuros profesionales muy cualificados, con mentes abiertas y con experiencia internacional.
Adquirir mayor conciencia y comprensión de otras culturas y países para desarrollar un sentido de la ciudadanía y la identidad europea.
Mejorar notablemente la competencia en lenguas extranjeras.
Cursar estudios reconocidos relacionados con su programa de estudios.
 

PROGRAMA DE INTERCAMBIO CON AMÉRICA DEL NORTE

Este programa promueve la movilidad del estudiantado de grado durante un semestre académico, a alguna de las universidades socias con las que se ha establecido convenio en los Estados Unidos.

 

PROGRAMA DE INTERCAMBIO CON ASIA, ÁFRICA Y OCEANÍA

El objetivo del programa es la movilidad del estudiantado de grado en universidades de Asia y Oceanía durante un semestre académico (generalmente las estancias se realizan en el segundo semestre del curso académico).

 

PROGRAMA DE INTERCAMBIO CON AMÉRICA LATINA

El objetivo de este programa es la movilidad del estudiantado de grado en universidades socias de América Latina para realizar estancias de un semestre académico (generalmente durante el segundo semestre del curso académico).

 

Movilidad en universidades españolas

SICUE

El programa SICUE tiene como objetivo la movilidad del estudiantado que cursa estudios de grado de realizar parte de sus estudios (estancias de un mínimo de cinco meses y de un máximo de nueve) en cualquier otra universidad pública o privada del Estado español con la que haya un convenio firmado, con la garantía de reconocimiento académico y de aprovechamiento, así como de adecuación a su perfil curricular. Se pretende conseguir que el estudiantado experimente sistemas docentes diferentes y que conozca la sociedad y cultura de otras autonomías, con la finalidad, sobre todo, de formación curricular y de proyección profesional.
    ''',
    'working_practices': '''
    ''',
    'basic_skills': '''
        CG01 - Capacidad de análisis y síntesis
        CG02 - Capacidad de organización y planificación
        CG03 - Comunicación oral y escrita en lengua nativa
        CG04 - Capacidad de comunicarse de forma oral y escrita en inglés en el ámbito de las tecnologías de la información y las comunicaciones.
        CG05 - Capacidad de gestión de la información
        CG06 - Resolución de problemas
        CG07 - Trabajo en equipo fomentando el respeto a la diversidad, la equidad y la igualdad de género.
        CG08 - Aprendizaje autónomo
        CG09 - Motivación por la calidad
    ''',
    'specific_skills': '''
EB01 - Capacidad para la resolución de los problemas matemáticos que puedan plantearse en la ingeniería. Aptitud para aplicar los conocimientos sobre: álgebra lineal; cálculo diferencial e integral; métodos numéricos; algorítmica numérica; estadística y optimización.
EB02 - Comprensión y dominio de los conceptos básicos de campos y ondas y electromagnetismo, teoría de circuitos eléctricos, circuitos electrónicos, principio físico de los semiconductores y familias lógicas, dispositivos electrónicos y fotónicos, y su aplicación para la resolución de problemas propios de la ingeniería.
EB03 - Capacidad para comprender y dominar los conceptos básicos de matemática discreta, lógica, algorítmica y complejidad computacional, y su aplicación para la resolución de problemas propios de la ingeniería.
EB04 - Conocimientos básicos sobre el uso y programación de los ordenadores, sistemas operativos, bases de datos y programas informáticos con aplicación en ingeniería.
EB05 - Conocimiento de la estructura, organización, funcionamiento e interconexión de los sistemas informáticos, los fundamentos de su programación, y su aplicación para la resolución de problemas propios de la ingeniería.
EB06 - Conocimiento adecuado del concepto de empresa, marco institucional y jurídico de la empresa. Organización y gestión de empresas.

ER01 - Capacidad para diseñar, desarrollar, seleccionar y evaluar aplicaciones y sistemas informáticos, asegurando su fiabilidad, seguridad y calidad, conforme a principios éticos y a la legislación y normativa vigente.
ER02 - Capacidad para planificar, concebir, desplegar y dirigir proyectos, servicios y sistemas informáticos en todos los ámbitos, liderando su puesta en marcha y su mejora continua y valorando su impacto económico y social.
ER03 - Capacidad para comprender la importancia de la negociación, los hábitos de trabajo efectivos, el liderazgo y las habilidades de comunicación en todos los entornos de desarrollo de software.
ER04 - Capacidad para elaborar el pliego de condiciones técnicas de una instalación informática que cumpla los estándares y normativas vigentes.
ER05 - Conocimiento, administración y mantenimiento de sistemas, servicios y aplicaciones informáticas.
ER06 - Conocimiento y aplicación de los procedimientos algorítmicos básicos de las tecnologías informáticas para diseñar soluciones a problemas, analizando la idoneidad y complejidad de los algoritmos propuestos.
ER07 - Conocimiento, diseño y utilización de forma eficiente los tipos y estructuras de datos más adecuados a la resolución de un problema.
ER08 - Capacidad para analizar, diseñar, construir y mantener aplicaciones de forma robusta, segura y eficiente, eligiendo el paradigma y los lenguajes de programación más adecuados.
ER09 - Capacidad de conocer, comprender y evaluar la estructura y arquitectura de los computadores, así como los componentes básicos que los conforman.
ER10 - Conocimiento de las características, funcionalidades y estructura de los Sistemas Operativos y diseñar e implementar aplicaciones basadas en sus servicios.
ER11 - Conocimiento y aplicación de las características, funcionalidades y estructura de los Sistemas Distribuidos, las Redes de Computadores e Internet y diseñar e implementar aplicaciones basadas en ellas.
ER12 - Conocimiento y aplicación de las características, funcionalidades y estructura de las bases de datos, que permitan su adecuado uso, y el diseño y el análisis e implementación de aplicaciones basadas en ellos.
ER13 - Conocimiento y aplicación de las herramientas necesarias para el almacenamiento, procesamiento y acceso a los Sistemas de información, incluidos los basados en web.
ER14 - Conocimiento y aplicación de los principios fundamentales y técnicas básicas de la programación paralela, concurrente, distribuida y de tiempo real.
ER15 - Conocimiento y aplicación de los principios fundamentales y técnicas básicas de los sistemas inteligentes y su aplicación práctica.
ER16 - Conocimiento y aplicación de los principios, metodologías y ciclos de vida de la ingeniería de software.
ER17 - Capacidad para diseñar y evaluar interfaces persona computador que garanticen la accesibilidad y usabilidad a los sistemas, servicios y aplicaciones informáticas.
ER18 - Conocimiento de la normativa y la regulación de la informática en los ámbitos nacional, europeo e internacional.

PFG - Ejercicio original a realizar individualmente y presentar y defender ante un tribunal universitario, consistente en un proyecto del ámbito de la tecnología específica de la Ingeniería en Informática escogida por el estudiante de entre las cuatro ofertadas (Ingeniería de Computadores, Ingeniería del software, Sistemas de información y Tecnologías de la información) de naturaleza profesional en el que se sinteticen e integren las competencias adquiridas en las enseñanzas.

IU01 - Capacidad de poseer espíritu emprendedor y de desarrollar la iniciativa empresarial en el ámbito de las tecnologías de la información y las comunicaciones
    ''',
    'transversal_skills': '''
    ''',
    'double_degree': False,
    'schedule': '',
    'subjects': '',
    'languages': '',
    'mentions': '''
    '''
}

# %%
degree_df = pd.DataFrame([DEGREE_DATA], columns=DEGREE_COLUMNS)

# %%
degree_df.to_csv('{}.csv'.format(DEGREE_NAME))
